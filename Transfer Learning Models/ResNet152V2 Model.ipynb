# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet152V2
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
import pandas as pd
import os

# %%
# Load CSV file with image labels
data_path = "C:\\Users\\USER\\Documents\\4-2  Thesis\\Dataset\\train_validate_set.csv"
image_dir = "C:\\Users\\USER\\Documents\\4-2  Thesis\\train_validation(1)"

# %%
# Load and preprocess the dataset
data = pd.read_csv(data_path)
data['file_path'] = data['image_id'].apply(lambda x: os.path.join(image_dir, x+".jpg"))
data['label'] = data['label'].astype(str)

# %%
# Parameters
img_height, img_width = 224, 224  # Image dimensions
batch_size = 32
epochs = 30

# %%
# Prepare Image Data Generator
data_gen = ImageDataGenerator(
    rescale=1.0 / 255,
    validation_split=0.2
)

train_gen = data_gen.flow_from_dataframe(
    dataframe=data,
    directory=image_dir,
    x_col='file_path',
    y_col='label',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

val_gen = data_gen.flow_from_dataframe(
    dataframe=data,
    directory=image_dir,
    x_col='file_path',
    y_col='label',
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 6523 validated image filenames belonging to 4 classes.
# Found 1630 validated image filenames belonging to 4 classes.

# %%
# Load ResNet152V2 model with pretrained weights and exclude top layer
base_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# %%
# Add custom classification layers
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
out = Dense(4, activation='softmax')(x)  # Adjust output layer for 4 classes

model = Model(inputs=base_model.input, outputs=out)

# %%
# Fine-tune the base model by unfreezing the last few layers
for layer in base_model.layers[-5:]:  # Adjust the number based on experimentation
    layer.trainable = True

# %%
# Compile the model with a slightly lower learning rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Add callbacks for dynamic learning rate adjustment and early stopping
callbacks = [
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        verbose=1
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1,
        restore_best_weights=True
    )
]

# %%
# Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=epochs,
    steps_per_epoch=train_gen.samples // batch_size,
    validation_steps=val_gen.samples // batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 203/203 [==============================] - 53s 183ms/step - loss: 0.6049 - accuracy: 0.7698 - val_loss: 0.7334 - val_accuracy: 0.7738 - lr: 1.0000e-04
# Epoch 2/30
# 203/203 [==============================] - 35s 169ms/step - loss: 0.3830 - accuracy: 0.8550 - val_loss: 0.5531 - val_accuracy: 0.8131 - lr: 1.0000e-04
# Epoch 3/30
# 203/203 [==============================] - 34s 167ms/step - loss: 0.2756 - accuracy: 0.8988 - val_loss: 0.6352 - val_accuracy: 0.7850 - lr: 1.0000e-04
# Epoch 4/30
# 203/203 [==============================] - 35s 170ms/step - loss: 0.1706 - accuracy: 0.9430 - val_loss: 0.5474 - val_accuracy: 0.8506 - lr: 1.0000e-04
# Epoch 5/30
# 203/203 [==============================] - 34s 167ms/step - loss: 0.1353 - accuracy: 0.9541 - val_loss: 0.6659 - val_accuracy: 0.7738 - lr: 1.0000e-04
# Epoch 6/30
# 203/203 [==============================] - 35s 169ms/step - loss: 0.1021 - accuracy: 0.9660 - val_loss: 0.7437 - val_accuracy: 0.8363 - lr: 1.0000e-04
# Epoch 7/30
# 203/203 [==============================] - 35s 171ms/step - loss: 0.0760 - accuracy: 0.9744 - val_loss: 0.5349 - val_accuracy: 0.8338 - lr: 1.0000e-04
# Epoch 8/30
# 203/203 [==============================] - 35s 169ms/step - loss: 0.0747 - accuracy: 0.9766 - val_loss: 0.6500 - val_accuracy: 0.8263 - lr: 1.0000e-04
# Epoch 9/30
# 203/203 [==============================] - 34s 167ms/step - loss: 0.0686 - accuracy: 0.9754 - val_loss: 1.0520 - val_accuracy: 0.8169 - lr: 1.0000e-04
# Epoch 10/30
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 203/203 [==============================] - 34s 167ms/step - loss: 0.0569 - accuracy: 0.9811 - val_loss: 0.9698 - val_accuracy: 0.8175 - lr: 1.0000e-04
# Epoch 11/30
# 203/203 [==============================] - 34s 168ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.5923 - val_accuracy: 0.8612 - lr: 5.0000e-05
# Epoch 12/30
# Restoring model weights from the end of the best epoch: 7.
# 203/203 [==============================] - 35s 169ms/step - loss: 0.0085 - accuracy: 0.9982 - val_loss: 0.6563 - val_accuracy: 0.8744 - lr: 5.0000e-05
# Epoch 12: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training and validation loss
def plot_loss(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss', marker='o')
    plt.plot(history.history['val_loss'], label='Validation Loss', marker='o')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss(history)

# %%
# Plot training and validation accuracy
import matplotlib.pyplot as plt
def plot_accuracy(history):
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()
    plt.show()

plot_accuracy(history)

# %%
# Save the model
model.save('ResNet152V2_Model_bl.h5')

# %%
# Evaluate the model
eval_result = model.evaluate(val_gen)
print(f"Validation Loss: {eval_result[0]}, Validation Accuracy: {eval_result[1]}")
